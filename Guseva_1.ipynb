# %% [markdown]
# # **ПРАКТИЧЕСКАЯ РАБОТА № 1. Часть 2**

# %% [markdown]
# # 1. Знакомство с языком Python

# %% [markdown]
# ## 1.1 Первая программа
#
# ---

# %% [markdown]
# Напишите в строке IN:
#
# ```python
# print('hello world')
# ```
#
# нажмите Ctrl + Enter

# %%
print('hello world')
#Это строка IN. здесь можно писать Ваш код. После знака # идет комментарий, который никак не влияет на выполнение кода, но позволяет программисту дать пояснение коду.
# Out:
# hello world

# %% [markdown]
# ![изображение_2023-02-03_001439108.png](data:image/png;base64,...)

# %% [markdown]
# Описание функции print в официальной документации Python.https://docs.python.org/3/library/functions.html#print
#
# Статья «Функции Print() в Python».
# https://www.internet-technologies.ru/articles/funkcii-print-v-python.html

# %% [markdown]
# 1. Сколько аргументов можно передавать в функцию для вывода на экран?
# 2. Как передать в функцию для вывода на экран несколько аргументов?
# 3. Что будет результатом выполнения команды print ('Hello' + 'World!')?

# %% [markdown]
# ## 1.2 Первая переменная
#
# ---

# %% [markdown]
# Присвойте переменной Х любое целое значение (например, x = 5) и нажмите Ctrl + Enter.
# На языке Python присваивание выполняется, в частности, с помощью символа «=».

# %%
x = 5

# %% [markdown]
# Выведите значение переменной Х с помощью функции print.

# %%
print(x)
# Out:
# 5

# %% [markdown]
# Научитесь завершать ввод команд автоматически. Для этого введите символы pr и получите print с помощью списка возможных вариантов завершения, который вызывается нажатием клавишы Tab. После выбору нужной команды с помощью стрелок на клавиаутре "Вверх" или "Вниз" нажмите Enter:
#
# ![image.png](data:image/png;base64,...)!

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ## 1.3 Введение в написание программ

# %% [markdown]
# Программа на языке Python состоит из набора инструкций. Каждая инструкция помещается на новую строку. Например:

# %%
print(2 + 3)
print('Hello')
print('Hello'+'World')
print('Hello','World')
# Out:
# 5
# Hello
# HelloWorld
# Hello World

# %% [markdown]
# Большую роль играют отступы. Неправильно поставленный отступ фактически является ошибкой. Например, в следующем случае мы получим ошибку, хотя код будет практически аналогичен приведенному выше:

# %%
print(2 + 3)
print('Hello')
# Out:
# 5
# Hello

# %% [markdown]
# Поэтому стоит помещать новые инструкции сначала строки. В этом одно из важных отличий пайтона от других языков программирования.
# Однако стоит учитывать, что некоторые конструкции языка могут состоять из нескольких строк. Например, условная конструкция if (если):

# %%
if 1 < 2:
    print('Hello')
# Out:
# Hello

# %% [markdown]
# В данном случае если 1 меньше 2, то выводится строка 'Hello'. И здесь уже должен быть отступ, так как инструкция print('Hello') используется не сама по себе, а как частьусловной конструкции if. Причем отступ, согласно руководству по оформлению кода, желательно делать из такого количества пробелов, которое кратно 4 (то есть 4, 8, 16 и т.д.). Хотя если отступов будет не 4, а 5, то программа также будет работать.

# %% [markdown]
# Таких конструкций не так много, поэтому особой путаницы по поводу где надо, а где не надо ставить пробелы, не должно возникнуть.

# %% [markdown]
# **Регистрозависимость**

# %% [markdown]
# Python - регистрозависимый язык, поэтому выражения print и Print или PRINT представляют разные выражения. И если вместо метода print для вывода на консоль мы попробуем использовать метод Print:

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# то у нас ничего не получится.

# %% [markdown]
# **Комментарии**

# %% [markdown]
# Для отметки, что делает тот или иной участок кода, применяются комментарии. При трансляции и выполнении программы интерпретатор игнорирует комментарии, поэтому они не оказывают никакого влияния на работу программы. Комментарии бывают строчные и блочные.
#
# Строчные комментарии предваряются знаком решетки - #. Они могут располагаться на отдельной строке:

# %%
# Вывод на консоль
# Сообщения Hello World
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# Любой набор символов после знака # представляет комментарий. То есть в примере выше первые две строки кода являются комментариями. Также они могут располагаться на той же строке, что и инструкции языка, после выполняемых  инструкций:

# %%
print('Hello world') # команда выводит на консоль сообщение Hello World
# Out:
# Hello world

# %% [markdown]
# В блочных комментариях до и после текста комментария ставятся три одинарные кавычки '''текст комментария'''. Например:

# %%
'''
    Вывод на консоль
    сообщения Hello World
'''
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# **Основные функции**

# %% [markdown]
# Python предоставляет ряд встроенных функций. Некоторые из них используются очень часто, особенно на начальных этапах изучения языка, поэтому рассмотрим их.

# %% [markdown]
# с функцией print() мы уже начали знакомиться выше. Продолжим знакомство с ней. Если нам необходимо вывести несколько значений на консоль, то мы можем передать их в функцию print через запятую:

# %%
print('Full name:', 'Tom', 'Smith')
# Out:
# Full name: Tom Smith

# %% [markdown]
# В итоге все переданные значения склеятся через пробелы в одну строку: Full name: Tom Smith

# %% [markdown]
# Если функция **print** отвечает за вывод, то функция **input** отвечает за ввод информации. В качестве необязательного параметра эта функция принимает приглашение к вводу и возвращает введенную строку, которую мы можем сохранить в переменную:

# %%
name = input('Введите имя')
print('Привет,', name)
# Out:
# Привет, Юлия

# %% [markdown]
# ## 1.4 Упражнения

# %% [markdown]
# 1. Отредактируйте код, что бы он выводил текст:
#
#    Добро пожаловать!

# %%
# данный код
# print("Hello world")

# требуемый вывод:
# Добро пожаловать!
print ('Добро пожаловать!')
# Out:
# Добро пожаловать!

# %% [markdown]
# 2. Допишите код, что бы получить вывод:
#
#    Функция print().

# %%
# данный код
my_text="Hello"
print(my_text)
# требуемый вывод:
# Функция print()
# Out:
# Hello

# %% [markdown]
# 3. Даны переменные name, surname и salary. Выведите требуемый текст.

# %%
# данный код
name = "Иван"
surname = "Петров"
salary = "90 000"
# требуемый вывод:
# Иван Петров зарабатывает 90 000 рублей
print(name, surname, 'зарабатывает', salary, 'рублей')
# Out:
# Иван Петров зарабатывает 90 000 рублей

# %% [markdown]
# 4. Напишите программу, которая спрашивает как Вас зовут, затем программа печатает «Привет, дорогой (ая) ‘ваше имя’. Рад знакомству!»

# %%
name = input('Как Вас зовут?')
print('Привет, дорогая', name, '. Рад знакомству!')
# Out:
# Привет, дорогая Юлия . Рад знакомству!

# %% [markdown]
# 5. Напишите программу, которая спрашивает ваше имя, ваш любимый цвет, а потом печатает «‘ваше имя’ любит ‘введённый цвет’»

# %%
name = input('Как Вас зовут?')
colour = input('Какой Ваш любимый цвет?')
print(name, 'любит', colour)
# Out:
# Юлия любит Розовый

# %% [markdown]
# 6. Напишите программу, которая выводит такое «окно» на экран. Размер окна может быть любым. Образец:
#
# ![image.png](data:image/png;base64,...)

# %%
print('==============================')
print('||                          ||')
print('||                          ||')
print('||          Привет          ||')
print('||          друг!           ||')
print('||                          ||')
print('||                          ||')
print('==============================')
# Out:
# ...
# ||                          ||
# ||                          ||
# ||          Привет          ||
# ||          друг!           ||
# ||                          ||
# ||                          ||
# ...

# %% [markdown]
# 7. Устраните ошибку в коде

# %%
#устраните ошибку в коде, вставьте недостающий отступ
if 5 > 2:
     print("Пять больше, чем два!")
# Out:
# Пять больше, чем два!

# %% [markdown]
# 8. Вставьте символ, которые изменит код на комментарий

# %%
# x = 7

# %% [markdown]
# 9. Используйте многострочную строку для создания многострочного комментария:

# %%
'''
    Это комментарий написан больше, чем в одной строке
    Это комментарий написан больше, чем в одной строке
    Это комментарий написан больше, чем в одной строке
'''
# Out:
# '\n    Это комментарий написан больше, чем в одной строке\n    Это комментарий написан больше, чем в одной строке\n    Это комментарий написан больше, чем в одной строке\n'

# %% [markdown]
# 10. Устраните ошибки

# %%
# устраните ошибки в коде
if 2 < 3:
    print('2 меньше 3')
# Out:
# 2 меньше 3

# %% [markdown]
# 11. Напишите программу, которая выводит на экран текст «Hello, World!» (с кавычками).
# Запустите и отладьте программный код.

# %%
'''
    Вывод на консоль сообщение «Hello, World!»
'''
print('«Hello, World!»')
# Out:
# «Hello, World!»

# %% [markdown]
# 12. Выведите на экран друг за другом три имени: Robert, Stannis, Renly. В результате на экране
# должно отобразиться:
# Robert
# Stannis
# Renly

# %%
print('Robert')
print('Stannis')
print('Renly')
# Out:
# Robert
# Stannis
# Renly

# %% [markdown]
# 13. Напишите программу, которая выводит указанный треугольник, состоящий из звездочек ('*').
# В результате на экране должно отобразиться:
# ![image.png](data:image/png;base64,...)

# %%
print('*')
print('**')
print('***')
print('****')
print('*****')
print('******')
print('*******')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# 14. На вход программе подается строка текста – имя человека. Напишите программу, которая выводит
# на экран приветствие в виде слова «Привет» (без кавычек), после которого должна стоять запятая
# и пробел, а затем введенное имя.
# Формат ввода:
# Тимур
# Формат вывода:
# Привет, Тимур

# %%
name = input('Имя человека')
print('Привет,', name)
# Out:
# Привет, Тимур

# %% [markdown]
# 15. На вход программе подается строка текста – название футбольной команды. Напишите
# программу, которая повторяет ее на экране со словами « - чемпион!» (без кавычек)
# Формат ввода:
# Барселона
# Формат вывода:
# Барселона - чемпион!

# %%
name = input('Название футбольной команды')
print(name, '- чемпион!')
# Out:
# Барселона - чемпион!

# %% [markdown]
# 16. Напишите программу, которая считывает три строки по очереди с клавиатуры, а затем выводит их
# в той же последовательности, каждую на отдельной строчке.
# Формат ввода:
# I was
# born
# this way
# Формат вывода:
# I was
# born
# this way

# %%
p = input('слово1')
s = input('слово2')
d = input('слово3')
print(p)
print(s)
print(d)
# Out:
# I was
# born
# this way

# %% [markdown]
# 17. Напишите программу, которая считывает три строки по очереди с клавиатуры, а затем выводит их
# в обратной последовательности, каждую на отдельной строчке.
# Формат ввода:
# Hello
# it's
# me
# Формат вывода:
# me
# it's
# Hello

# %%
p = input('слово1')
s = input('слово2')
d = input('слово3')
print(d)
print(s)
print(p)
# Out:
# me
# it's
# Hello

# %% [markdown]
# 18. Напишите программу, которая считывает строку-разделитель и три строки, а затем выводит
# указанные строки через разделитель.
# ![image.png](data:image/png;base64,...)

# %%
q = input('разделитель')
w = input('строка1')
e = input('строка2')
t = input('строка3')
print(w, q, e, q, t)
# Out:
# Раз * Два * Три

# %% [markdown]
# 19. Напишите программу, которая приветствует пользователя, выводя слово «Привет» (без кавычек),
# после которого должна стоять запятая и пробел, а затем введенное имя и восклицательный знак.
# ![image.png](data:image/png;base64,...)

# %%
name = input('Имя')
print('Привет,', name, '!')
# Out:
# Привет, Тирион !

# %% [markdown]
# 20. Напишите программу, которая выведет на экран фразы:
#     ![image.png](data:image/png;base64,...)

# %%
print('''"Nikolai's favorite movie - "The Last Hero""''')
print('"Любимый фильм Николая - "Последний богатырь""')
# Out:
# "Nikolai's favorite movie - "The Last Hero""
# "Любимый фильм Николая - "Последний богатырь""

# %% [markdown]
# Критерии оценки работы:
# • выполнены без ошибок и недочетов 10 заданий - выставляется отметка «отлично»;
# • выполнены без ошибок и недочетов 8-9 заданий - выставляется отметка «хорошо»;
# • выполнены без ошибок и недочетов 6-7 заданий - выставляется отметка «удовлетворительно»;
# • выполнено без ошибок и недочетов и менее 5 заданий - выставляется отметка
# «неудовлетворительно».
# Студенты, получившие за работу неудовлетворительную оценку, должны выполнить ее повторно.

# %% [markdown]
# 21. Запросите слово и выведите его 3 раза подряд без пробелов (например: "HiHiHi").

# %%
e = input('слово')
print(e*3)
# Out:
# HaHaHa

# %% [markdown]
# 22. Спросите имя и фамилию, выведите в формате:
# "Фамилия: [фамилия], Имя: [имя]"

# %%
name = input('Назовите свое имя')
surname = input('Назовите свою фамилию')
print('Фамилия:', surname, 'Имя:', name)
# Out:
# Фамилия: Гусева Имя: Юлия

# %% [markdown]
# 23. Запросите строку и выведите её в верхнем регистре (самостоятельно найдите метод для изменения регистра строковых величин в python)

# %%
text = input('Текст')
print(text.upper())
# Out:
# ВСЕМ ПРИВЕТИК

# %% [markdown]
# 24. Запросите слово и выведите: "В слове '[слово]' [N] букв" (используйте len()).

# %%
slovo = input('слово')
print('В слове', slovo, len(slovo), 'букв')
# Out:
# В слове Змееед 6 букв

# %% [markdown]
# 25. Запросите текст и выведите его 3 раза, каждый с новой строки, используя один print()

# %%
text = input('текст')
print(text, text, text, sep='\n')
# Out:
# Miu
# Miu
# Miu

# %% [markdown]
# 26. Запросите имя, фамилию и год рождения, выведите одной строкой:
# "[имя]_[фамилия]_[год]" (через подчёркивание).

# %%
name = input('Назовите свое имя')
surname = input('Назовите свою фамилию')
year = input('Назовите свой год рождения')
print(name, surname, year, sep='_')
# Out:
# Юлия_Гусева_2005

# %% [markdown]
# 27. Найдите и исправьте ошибки в коде.

# %%
name = input('Введите имя:')
print('Ваше имя:', name)
# Out:
# Ваше имя: Юлия

# %% [markdown]
# 28. Найдите и исправьте ошибки в коде.

# %%
city = input("Город: ")
print("Вы живёте в:", city)
# Out:
# Вы живёте в: Тюмень

# %% [markdown]
# 29. Найдите и исправьте ошибки в коде.

# %%
age = input("Возраст: ")
print("Вам", age, "лет.")
# Out:
# Вам 20 лет.

# %% [markdown]
# 30. Найдите и исправьте ошибки в коде.

# %%
text = input("Текст:")
print(text * 3)
# Out:
# ХиХиХи

# %% [markdown]
# ## 1.5 Функция print(). Разделители и escape-последовательности

# %% [markdown]
# У функции print() есть дополнительные аргументы — значения, с помощью которых можно модифицировать вывод данных. Их следует передавать во время вызова. С ними синтаксис print() выглядит так:

# %%
print(objects, sep=' ', end='\n')
# Out:
# Failed to interrupt the Kernel.
#
# Unable to start Kernel 'Python 3.14.0' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# В ней:
# objects — один или несколько объектов, которые нужно вывести;
# sep — разделитель между объектами (по умолчанию пробел);
# end — символ завершения строки (по умолчанию перевод строки);
# file — объект файла, в который направлен вывод;
# flush — принудительный сброс буфера вывода.
# Рассмотрим подробно, как устроен каждый из аргументов и как всё это можно использовать на практике.

# %% [markdown]
# Аргумент **sep** определяет, какой разделитель Python будет использовать между элементами функции print(). По умолчанию ставится пробел:

# %%
print("Мир", "Труд", "Май")
# Вывод: Мир Труд Май
# Out:
# Мир Труд Май

# %% [markdown]
# Но можно поставить, например, восклицательный знак:

# %%
print("Мир", "Труд", "Май", sep="! ")
# Вывод: Мир! Труд! Май
# Out:
# Мир! Труд! Май

# %% [markdown]
# Важно отметить, что sep вставляет разделитель только между объектами, поэтому в конце нашей строки восклицательного знака нет.
#
# sep можно использовать и для «склеивания» нескольких объектов в одну строку:

# %%
print("a", "b", "c", sep="")   # Вывод: abc
# Out:
# abc

# %% [markdown]
# Аргумент **end** функции print() в Python
# Аргумент end похож на sep, но ставит знак не между объектами, а после них. По умолчанию в конце каждой строки Python ставит символ перевода строки (\n).
#
# С помощью end можно добавить любой знак в конце строки:

# %%
print("Мир", "Труд", "Май", end="!")
# Вывод: Мир Труд Май!
print("Мир", "Труд", "Май", sep="! ", end="!")
# Вывод: Мир! Труд! Май!
# Out:
# Мир Труд Май!Мир! Труд! Май!

# %% [markdown]
# **Escape-последовательности**

# %% [markdown]
# Escape-символы или последовательности являются недопустимыми символами для Python и никогда не печатаются как часть вывода. Когда в программировании на Python используется обратная косая черта, это позволяет программе экранировать следующие символы.
# ![image.png](data:image/png;base64,...)

# %%
#Напиши код с картинки выше сюда
txt = 'Guru\n99!'
print(txt)
# Out:
# Guru
# 99!

# %% [markdown]
# Escape-последовательности
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Упражнения**

# %% [markdown]
# 31. Выведите дату в формате дд/мм/гггг используя три переменные (день, месяц, год) и параметр sep.

# %%
day = input('Введите день')
month = input('Введите месяц')
year = input('Введите год')
print(day, month, year, sep='/')
# Out:
# 04/06/2005

# %% [markdown]
# 32. Выведите три слова: "Имя", "Фамилия", "Возраст" через табуляцию (\t), используя один вызов print()

# %%
print('Имя','Фамилия','Возраст', sep='\t')
# Out:
# Имя	Фамилия	Возраст

# %% [markdown]
# 33. Выведите слово в рамке, используя только один print():
# ![image.png](data:image/png;base64,...)

# %%
print('============\n|', 'Сюрприз!', '|\n============')
# Out:
# ...
# | Сюрприз! |
# ...

# %% [markdown]
# 34. Выведите адрес в формате:
# ![image.png](data:image/png;base64,...)

# %%
print('Улица: [улица]\nГород: [город]\nИндекс: [индекс]')
# Out:
# Улица: [улица]
# Город: [город]
# Индекс: [индекс]

# %% [markdown]
# 35. Выведите корректный путь: **C:\new_folder\project** используя escape-последовательности.

# %%
print('C:\\new_folder\\project')
# Out:
# C:\new_folder\project

# %% [markdown]
# 36. Выведите фразу: Он сказал: "Привет!" с помощью экранирования кавычек.

# %%
print('Он сказал: \"Привет!\"')
# Out:
# Он сказал: "Привет!"

# %% [markdown]
# 37. Выведите два слова "Hello" и "world" в одной строке без пробела между ними, используя end.

# %%
print('Hello', end='')
print('world')
# Out:
# Helloworld

# %% [markdown]
# 38. Выведите три числа (1, 2, 3) через разделитель " ... " с помощью sep.

# %%
print('1', '2', '3', sep='...')
# Out:
# 1...2...3

# %% [markdown]
# 39. Выведите три слова так, чтобы каждое начиналось с новой строки и отступа (табуляции):
#     ![image.png](data:image/png;base64,...)

# %%
print('\tПервое\n\t\tВторое\n\t\t\tТретье')
# Out:
# 	Первое
# 		Второе
# 			Третье

# %% [markdown]
# 40. Выведите три слова через ->: "Начало" -> "Середина" -> "Конец"

# %%
print('\"Начало\"', '\"Середина\"', '\"Конец\"', sep='->')
# Out:
# "Начало"->"Середина"->"Конец"

# %% [markdown]
# 41. Выведите котика используя один print:
#    ![image.png](data:image/png;base64,...)

# %%
print('/\\_/\\\n(o.o)\n> ^ <')
# Out:
# /\_/\
# (o.o)
# > ^ <

# %% [markdown]
# ## 1.6 f-строки

# %% [markdown]
#  f-строки вступают в дело, чтобы помочь с форматированием. Также известные как «форматированные строковые литералы», f-strings являются строковыми литералами с «f» в начале и фигурные скобки, содержащие выражения, которые в дальнейшем будут заменены своими значениями. Выражения оцениваются по мере выполнения и затем форматируются при помощи протокола __format__ . Рассмотрим подробнее, как именно f-strings могут упростить вам жизнь.

# %%
name = "Eric"
age = 74

print(f"Hello, {name}. You are {age}.")
# Вывод: 'Hello, Eric. You are 74.'
# Out:
# Hello, Eric. You are 74.

# %% [markdown]
# Вы также можете использовать заглавную букву F:

# %%
print(F"Hello, {name}. You are {age}.")
# Вывод: 'Hello, Eric. You are 74.'
# Out:
# Hello, Eric. You are 74.

# %% [markdown]
# **Произвольные выражения**
# Так как f-строки оцениваются по мере выражения, вы можете внести любую или все доступные выражения Python в них. Это позволит вам делать интересные вещи, например следующее:

# %%
print(f"{2 * 37}")
# Вывод: '74'
# Out:
# 74

# %% [markdown]
# Также вы можете вызывать функции. Пример:

# %%
# def - обозначение начала функции в python
def to_lowercase(input):
    return input.lower()

name = "Eric Idle"

print(f"{to_lowercase(name)} is funny.")
# Вывод: 'eric idle is funny.'
# Out:
# eric idle is funny.

# %% [markdown]
# Также вы можете вызывать метод напрямую:

# %%
print(f"{name.lower()} is funny.")
# Вывод: 'eric idle is funny.'
# Out:
# eric idle is funny.

# %% [markdown]
# **Многострочные F-Strings**
# У вас могут быть многострочные f-strings:

# %%
name = "Eric"
profession = "comedian"
affiliation = "Monty Python"

message = (
    f"Hi {name}. "
    f"You are a {profession}. "
    f"You were in {affiliation}."
)

print(message)
# Вывод: 'Hi Eric. You are a comedian. You were in Monty Python.'
# Out:
# Hi Eric. You are a comedian. You were in Monty Python.

# %% [markdown]
# Однако помните о том, что вам нужно разместить f вначале каждой строки. Следующий код не будет работать:

# %%
message = (
    f"Hi {name}. "
    "You are a {profession}. "
    "You were in {affiliation}."
)

print(message)
# Вывод: 'Hi Eric. You are a {profession}. You were in {affiliation}.'
# Out:
# Hi Eric. You are a {profession}. You were in {affiliation}.

# %% [markdown]
# Если вы не внесете f в начале каждой индивидуальной строки, то получите обычную, старую версию строк, без приятных новшеств.
#
# Если вы хотите размножить строки по нескольким линиям, у вас также есть возможность избежать возвратов при помощи \:

# %%
message = f"Hi {name}. " \
          f"You are a {profession}. " \
          f"You were in {affiliation}."

print(message)
# Вывод: 'Hi Eric. You are a comedian. You were in Monty Python.'
# Out:
# Hi Eric. You are a comedian. You were in Monty Python.

# %% [markdown]
# Но вот что произойдет, если вы используете «»»:

# %%
message = f"""
    Hi {name}.
    You are a {profession}.
    You were in {affiliation}.
"""

print(message)
# Вывод: '\n    Hi Eric.\n    You are a comedian.\n    You were in Monty Python.\n'
# Out:
#     Hi Eric.
#     You are a comedian.
#     You were in Monty Python.

# %% [markdown]
# **Python F-Строки: Детали**
# На данный момент мы узнали почему f-строки так хороши, так что вам уже может быть интересно их попробовать в работе. Рассмотрим несколько деталей, которые нужно учитывать:
#
# **Кавычки**
# Вы можете использовать несколько типов кавычек внутри выражений. Убедитесь в том, что вы не используете один и тот же тип кавычек внутри и снаружи f-строки.
#
# Этот код будет работать:

# %%
print(f"{'Eric Idle'}")
# Вывод: 'Eric Idle'
# Out:
# Eric Idle

# %% [markdown]
# И этот тоже:

# %%
print(f'{"Eric Idle"}')
# Вывод: 'Eric Idle'
# Out:
# Eric Idle

# %% [markdown]
# Вы также можете использовать тройные кавычки:

# %%
print(f"""Eric Idle""")
# Вывод: 'Eric Idle'
# Out:
# Eric Idle

# %%
print(f'''Eric Idle''')
# Вывод: 'Eric Idle'
# Out:
# Eric Idle

# %% [markdown]
# Если вам понадобиться использовать один и тот же тип кавычек внутри и снаружи строки, вам может помочь \:

# %%
print(f"The \"comedian\" is {name}, aged {age}.")
# Вывод: 'The "comedian" is Eric Idle, aged 74.'
# Out:
# The "comedian" is Eric, aged 74.

# %% [markdown]
# **Скобки**
# Чтобы скобки появились в вашей строке, вам нужно использовать двойные скобки:

# %%
print(f"{{74}}")

# Вывод: '{ 74 }'
# Out:
# {74}

# %% [markdown]
# Обратите внимание на то, что использование тройных скобок приведет к тому, что в строке будут только одинарные:

# %%
print( f"{{{74}}}" )

# Вывод: '{ 74 }'
# Out:
# {74}

# %% [markdown]
# Однако, вы можете получить больше отображаемых скобок, если вы используете больше, чем три скобки:

# %%
print(f"{{{{74}}}}")

# Вывод: '{{74}}'
# Out:
# {{74}}

# %% [markdown]
# **Упражнения**

# %% [markdown]
# 42. Создайте переменные name = "Анна" и age = 25. Выведите строку: "Меня зовут Анна, мне 25 лет" используя f-string

# %%
name = 'Анна'
age = '25'
print(f'"Меня зовут {name}, мне {age} лет"')
# Out:
# "Меня зовут Анна, мне 25 лет"

# %% [markdown]
# 43. Даны a = 7 и b = 3. Используя одну f-string, выведите:
# "7 + 3 = 10, 7 * 3 = 21".

# %%
a, b = 7, 3
print(f'"{a} + {b} = {a+b},{a} * {b} = {a*b}"')
# Out:
# "7 + 3 = 10,7 * 3 = 21"

# %% [markdown]
# 44. Создайте price = 49.9915. Выведите цену в формате: "Цена: 49.99 руб." (2 знака после запятой).

# %%
price = 49.9915
print(f'Цена: {price:.2f} руб.')
# Out:
# Цена: 49.99 руб.

# %% [markdown]
# 45. Выведите текущую дату в формате: "Сегодня: 06 августа 2025"

# %%
from datetime import datetime
now = datetime.now()
print(f'Сегодня: {now.strftime('%d %B %Y')}')
# Out:
# Сегодня: 01 December 2025

# %% [markdown]
# 46. Дано ratio = 0.756. Выведите: "Процент: 75.6%"

# %%
ratio = 0.756
print(f"Процент: {ratio*100:.1f}%")
# Out:
# Процент: 75.6%

# %% [markdown]
# 47. text = "Привет" выведите: "Текст: 'Привет'" (с кавычками)

# %%
text = 'Привет'
print(f'Текст:\'{text}\'')
# Out:
# Текст:'Привет'

# %% [markdown]
# 48. Упражнения с ошибками (найти и исправить).

# %%
name = "Мария"
print(f"Привет, {name}!")  # Ожидается: "Привет, Мария!"
# Out:
# Привет, Мария!

# %% [markdown]
# 49. Упражнения с ошибками (найти и исправить)

# %%
x, y = 10, 2
print(f"Результат: {x} / {y} = {x / y:.0f}")  # Ожидается: "Результат: 10 / 2 = 5"
# Out:
# Результат: 10 / 2 = 5

# %% [markdown]
# 50. Упражнения с ошибками (найти и исправить)

# %%
first_name = "Алексей"
last_name = "Иванов"
print(f'"{first_name} {last_name}"')  # Ожидается: "Алексей Иванов"
# Out:
# "Алексей Иванов"

# %% [markdown]
# 51. Создайте переменные title = "Отчёт" и value = 100. Разбейте f-string на несколько строк используя только один print:
#    ![image.png](data:image/png;base64,...)

# %%
title = 'Отчет'
value = '100'
Variables = f"""
    Заголовок: {title}
    Значение: {value}
"""
print(Variables)
# Out:
#     Заголовок: Отчет
#     Значение: 100

# %% [markdown]
# ## 1.7 % - оператор форматирования строки

# %% [markdown]
# **Оператор %** по отношению к строкам выполняет операцию форматирования и вставки таким образом, что объект, стоящий справа от него, встраивается согласно определенным правилам в строку слева от него:

# %%
#не надо запускать
string % value

# %% [markdown]
# Такой способ форматирования считается старым потому, что заимствован из функции printf языка C, а в Python кроме него появились другие способы вставки данных в "строки-шаблоны". Однако в ряде случаев удобнее использовать оператор %.

# %% [markdown]
# **Вывод вещественного числа с заданной точностью**
# Оператор деления / возвращает вещественное число. Если количество знаков после запятой бесконечно, интерпретатор Python выведит его с большим количеством знаков в дробной части:

# %%
a = 4 / 3
print(a)
#Вывод: 1.3333333333333333
# Out:
# 1.3333333333333333

# %% [markdown]
# С помощью оператора форматирования строки % можно выполнить округление числа до требуемой точности. Например, оставить только два знака после запятой. Для этого внутри строки, то есть в кавычках, записывают комбинацию символов, которая начинается со знака %. Далее ставят точку. Число после точки обозначает количество знаков после запятой. Символ f обозначает вещественный тип данных float.

# %% [markdown]
# Типы преобразования:
# d / i  - Знаковое целое. Десятичный формат.
# e, E - С плавающей запятой (нижний и верхний регистр соответственно). Экспоненциальный формат.
# f, F - С плавающей запятой. Десятичный формат: 2.7 3.1
# s - Строка. Испольует str()
# % - Используется для получения символа % в результирующей строке.

# %%
a = 4 / 3
print('%.2f' % a)
#Вывод: 1.33
# Out:
# 1.33

# %%
a = 4 / 3
print('%.3f' % a)
#Вывод: 1.333
# Out:
# 1.333

# %% [markdown]
# Обратите внимание, переменная **a** содержит число с большим количеством знаков в дробной части. Строка '1.33' является результатом выполнения выражения '%.2f' % a. Функции print() передается готовая строка '1.33'. Предварительно эту строку можно было бы присвоить отдельной переменной:

# %%
a = 4 / 3
b = '%.2f' % a
print(b)
# Out:
# 1.33

# %% [markdown]
# С другой стороны, по правую сторону от оператора форматирования строки не обязательно указывать переменную. Чаще здесь записывают непосредственно выражение. При этом берут его в скобки.

# %%
print('%.2f' % (4 / 3))
#Вывод: 1.33
# Out:
# 1.33

# %% [markdown]
# Строка, содержащая в себе спецификаторы преобразования, также может содержать обычные символы:

# %%
print('A = %.1f, B = %d' % (3, 4))
#Вывод: A = 3.0, B = 4
# Out:
# A = 3.0, B = 4

# %% [markdown]
# Символ d в формате вставки обозначает целое число (тип int).
# Оператор форматирования строк выполняет округление вещественных чисел, а не простое отбрасывание "лишних" цифр:

# %%
print('%.2f, %.2f' % (0.123, 0.126))
#Вывод: 0.12, 0.13
# Out:
# 0.12, 0.13

# %% [markdown]
# **Вывод данных в поля заданной ширины**
# Бывает данные надо вывести в виде таблицы. Это значит, что каждый элемент данных выводится в поле определенной ширины, которая измеряется в знакоместах.
# Например, вместо подобного вывода:
# ![image.png](data:image/png;base64,...)
#
# надо получить:
# ![image.png](data:image/png;base64,...)
# Для таких случаев в формате вставки элемента данных в строку указывается ширина поля (количество знакомест). Делается это сразу после знака процента.

# %%
print('%-7s %5d %8.1f' % ('First', 483, 1.1))
print('%-7s %5d %8.1f' % ('Second', 9, 10.65))
# Out:
# First     483      1.1
# Second      9     10.7

# %% [markdown]
# Знак "минус" заставляет данные выравниваться по левому краю. По умолчанию они выравниваются по правому:

# %%
print('%7s %5d' % ('First', 483))
print('%7s %5d' % ('Second', 9))
# Out:
#   First   483
#  Second     9

# %% [markdown]
# **Вывод данных в определенном формате**
# Например, может понадобиться вывести время: 16 часов 30 минут

# %%
s = '%2d часов\t%02d минут' % (16, 30)
print(s)
# Out:
# 16 часов	30 минут

# %% [markdown]
# **Упражнения**

# %% [markdown]
# 52. Используя оператор %, выведите: "Привет, Анна!" (переменная name = "Анна").

# %%
name = 'Анна'
print('Привет, %s!' % name)
# Out:
# Привет, Анна!

# %% [markdown]
# 53. Даны product = "яблоки" и count = 5. Выведите: "Купил 5 яблок"

# %%
product = 'яблок'
count = 5
print('Купил %d %s' % (count, product))
# Out:
# Купил 5 яблок

# %% [markdown]
# 54. Для x = 10 и y = 3 выведите: "10 + 3 = 13".

# %%
x, y = 10, 3
print('%d + %d = %d' % (x, y, x+y))
# Out:
# 10 + 3 = 13

# %% [markdown]
# 55. Выведите число pi = 3.14159 с двумя знаками после запятой: "Pi: 3.14"

# %%
pi = 3.14159
print('Pi: %.2f' % pi)
# Out:
# Pi: 3.14

# %% [markdown]
# 56. Выведите число 42 в поле шириной 5 символов: " 42"

# %%
print('%5d' % 42)
# Out:
#    42

# %% [markdown]
# 57. Для name = "Alex" и score = 95.5 выведите: "Alex: 95.50 баллов" (ширина 10 символов для числа, 2 знака после запятой).

# %%
name = 'Alex'
score = 95.5
print('%s: %10.2f баллов' % (name, score))
# Out:
# Alex:      95.50 баллов

# %% [markdown]
# 58. Упражнения с ошибками (найти и исправить). Ошибка 1 (порядок аргументов):

# %%
print("%s купил %d яблок" % ("Петр", 5))
# Ожидается: "Петр купил 5 яблок"
# Out:
# Петр купил 5 яблок

# %% [markdown]
# 59.  Упражнения с ошибками (найти и исправить). Ошибка 2 (недостаточно аргументов):

# %%
print("%s %s" % ("Hello", "World"))
# Ожидается: "Hello World"
# Out:
# Hello World

# %% [markdown]
# 60. Упражнения с ошибками (найти и исправить). Ошибка 4 (неправильный спецификатор):

# %%
print("%d" % 10)
# Ожидается: "10"
# Out:
# 10
